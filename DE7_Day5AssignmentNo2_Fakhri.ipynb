# %%
pip install gql
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.0/74.0 kB 2.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 203.2/203.2 kB 8.1 MB/s eta 0:00:00
# ...

# %%
import requests

# Token akses GitHub
token = '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'

# Header otentikasi
headers = {
    'Authorization': f'Bearer {token}',
    'Content-Type': 'application/json',
}

# Query GraphQL
query = '''
query {
  repository(owner: "fakhriazis", name: "go-bank") {
    name
    description
    stargazerCount
    issues(first: 5, states: OPEN) {
      nodes {
        title
        body
        createdAt
      }
    }
    pullRequests(first: 5, states: OPEN) {
      nodes {
        title
        body
        createdAt
        author {
          login
        }
      }
    }
  }
}
'''

# Permintaan HTTP POST
response = requests.post(
    'https://api.github.com/graphql',
    headers=headers,
    json={'query': query}
)

# Periksa status kode dan tangani kesalahan
if response.status_code == 200:
    data = response.json()

    # Menampilkan informasi repositori
    repo = data['data']['repository']
    print(f"Repository: {repo['name']}")
    print(f"Description: {repo['description']}")
    print(f"Stars: {repo['stargazerCount']}")


else:
    print(f"Request failed with status code {response.status_code}: {response.json()}")
# Out:
# Repository: go-bank
# Description: ini adalah project back-end membuat aplikasi bank sederhana menggunakan golang
# Stars: 1
